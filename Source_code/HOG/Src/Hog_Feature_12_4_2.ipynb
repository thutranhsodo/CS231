# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import joblib
import numpy as np
import matplotlib.pyplot as plt
from skimage.feature import hog
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %%
def load_images(image_folder):
    images = []
    labels = []
    class_names = sorted(os.listdir(image_folder))  # Đã sửa: Thêm `sorted`
    for label, class_name in enumerate(class_names):
        class_path = os.path.join(image_folder, class_name)
        for img_name in os.listdir(class_path):
            img_path = os.path.join(class_path, img_name)
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            if img is not None:
                images.append(img)
                labels.append(label)
    return np.array(images), np.array(labels), class_names

# %%
def process_image(image, orientations, pixels_per_cell, cells_per_block, block_norm):
    return hog(
        image,
        orientations=orientations,
        pixels_per_cell=pixels_per_cell,
        cells_per_block=cells_per_block,
        block_norm=block_norm
    )

# %%
def extract_hog_feature(images, orientations, pixels_per_cell, cells_per_block, block_norm):
    features = []
    for image in images:
        feature = process_image(image, orientations, pixels_per_cell, cells_per_block, block_norm)
        features.append(feature)
    return np.array(features)

# %%
#Hàm huấn luyện model với GridSearch
def train_model_with_gridsearch(X_train, y_train, model, param_grid):
  grid_search = GridSearchCV(
      estimator = model,
      param_grid = param_grid,
      cv=5,
      scoring='accuracy',
      n_jobs=-1)
  grid_search.fit(X_train, y_train)
  return grid_search

# %%
#Hàm đánh giá và in kết quả
def evaluate_model(model, X_test, y_test, class_names):
    y_pred = model.predict(X_test)
    report = classification_report(y_test, y_pred, target_names=class_names)
    print("\nClassification Report:")
    print(report)
    return report

# %%
#Lưu kết quả huấn luyện
def save_results(results_file, cv_results):
  with open(results_file, 'w') as f:
    for mean_score, params in zip(cv_results['mean_test_score'], cv_results['params']):
      line = f"Mean Accuracy: {mean_score:.6f}, Parameters: {params}"
      print(line)
      f.write(line + '\n')

# %%
#Lưu model đã huấn luyện
def save_model(model, model_path, model_name):
    os.makedirs(model_path, exist_ok=True)
    model_file = os.path.join(model_path, model_name)
    joblib.dump(model, model_file)
    print(f"Model saved to {model_file}")
    return model_file

# %%
#dataset_path = '/content/drive/My Drive/CS231/Dataset/'
dataset_path = '/content/drive/MyDrive/CS231_DT/Dataset'

train_folder = os.path.join(dataset_path, 'train')
X_train, y_train, class_names = load_images(train_folder)

test_folder = os.path.join(dataset_path, 'test')
X_test, y_test, _ = load_images(test_folder)

# %%
orientations = 12
pixels_per_cell = (4, 4)
cells_per_block = (2, 2)
block_norm = 'L2-Hys'

# %%
hog_train_feature = extract_hog_feature(X_train, orientations, pixels_per_cell, cells_per_block, block_norm)
hog_test_feature = extract_hog_feature(X_test, orientations, pixels_per_cell, cells_per_block, block_norm)

# %%
model_path = '/content/drive/MyDrive/CS231_DT/Source_code/Model'
results_path = '/content/drive/MyDrive/CS231_DT/Source_code/Result'

# %%
#Huấn luyện và đánh giá KNN
knn_params = {
    'n_neighbors': range(1, 15),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
    }

cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

knn_grid = GridSearchCV(
    estimator=KNeighborsClassifier(),
    param_grid=knn_params,
    scoring='accuracy',  # Có thể thay đổi scoring theo yêu cầu
    cv=cv,               # Chỉ định đối tượng cross-validation
    verbose=1
)

knn_grid.fit(hog_train_feature, y_train)

os.makedirs(results_path, exist_ok=True)
results_file = os.path.join(results_path, f'result_knn_12_4_2.txt')
save_results(results_file, knn_grid.cv_results_)

print("Best parameters for KNN:", knn_grid.best_params_)
print("Best KNN score:", knn_grid.best_score_)

evaluate_model(knn_grid.best_estimator_, hog_test_feature, y_test, class_names)

save_model(knn_grid.best_estimator_, model_path, f'knn_model_12_4_2.pkl')
# Out:
# Fitting 5 folds for each of 56 candidates, totalling 280 fits
# Mean Accuracy: 0.870976, Parameters: {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'uniform'}
# Mean Accuracy: 0.870976, Parameters: {'metric': 'euclidean', 'n_neighbors': 1, 'weights': 'distance'}
# Mean Accuracy: 0.833689, Parameters: {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'uniform'}
# Mean Accuracy: 0.870976, Parameters: {'metric': 'euclidean', 'n_neighbors': 2, 'weights': 'distance'}
# Mean Accuracy: 0.862885, Parameters: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Mean Accuracy: 0.879016, Parameters: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# Mean Accuracy: 0.869930, Parameters: {'metric': 'euclidean', 'n_neighbors': 4, 'weights': 'uniform'}
# Mean Accuracy: 0.876991, Parameters: {'metric': 'euclidean', 'n_neighbors': 4, 'weights': 'distance'}
# Mean Accuracy: 0.862860, Parameters: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'uniform'}
# Mean Accuracy: 0.874966, Parameters: {'metric': 'euclidean', 'n_neighbors': 5, 'weights': 'distance'}
# Mean Accuracy: 0.865885, Parameters: {'metric': 'euclidean', 'n_neighbors': 6, 'weights': 'uniform'}
# Mean Accuracy: 0.877976, Parameters: {'metric': 'euclidean', 'n_neighbors': 6, 'weights': 'distance'}
# Mean Accuracy: 0.844713, Parameters: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'uniform'}
# Mean Accuracy: 0.858830, Parameters: {'metric': 'euclidean', 'n_neighbors': 7, 'weights': 'distance'}
# Mean Accuracy: 0.858850, Parameters: {'metric': 'euclidean', 'n_neighbors': 8, 'weights': 'uniform'}
# Mean Accuracy: 0.871920, Parameters: {'metric': 'euclidean', 'n_neighbors': 8, 'weights': 'distance'}
# Mean Accuracy: 0.850774, Parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'uniform'}
# Mean Accuracy: 0.861845, Parameters: {'metric': 'euclidean', 'n_neighbors': 9, 'weights': 'distance'}
# Mean Accuracy: 0.843724, Parameters: {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'uniform'}
# Mean Accuracy: 0.858830, Parameters: {'metric': 'euclidean', 'n_neighbors': 10, 'weights': 'distance'}
# Mean Accuracy: 0.842729, Parameters: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'uniform'}
# Mean Accuracy: 0.857814, Parameters: {'metric': 'euclidean', 'n_neighbors': 11, 'weights': 'distance'}
# Mean Accuracy: 0.843714, Parameters: {'metric': 'euclidean', 'n_neighbors': 12, 'weights': 'uniform'}
# Mean Accuracy: 0.855804, Parameters: {'metric': 'euclidean', 'n_neighbors': 12, 'weights': 'distance'}
# Mean Accuracy: 0.828598, Parameters: {'metric': 'euclidean', 'n_neighbors': 13, 'weights': 'uniform'}
# Mean Accuracy: 0.843693, Parameters: {'metric': 'euclidean', 'n_neighbors': 13, 'weights': 'distance'}
# Mean Accuracy: 0.825588, Parameters: {'metric': 'euclidean', 'n_neighbors': 14, 'weights': 'uniform'}
# Mean Accuracy: 0.839678, Parameters: {'metric': 'euclidean', 'n_neighbors': 14, 'weights': 'distance'}
# Mean Accuracy: 0.678473, Parameters: {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'uniform'}
# Mean Accuracy: 0.678473, Parameters: {'metric': 'manhattan', 'n_neighbors': 1, 'weights': 'distance'}
# Mean Accuracy: 0.599863, Parameters: {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'uniform'}
# Mean Accuracy: 0.678473, Parameters: {'metric': 'manhattan', 'n_neighbors': 2, 'weights': 'distance'}
# Mean Accuracy: 0.625060, Parameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}
# Mean Accuracy: 0.673443, Parameters: {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'distance'}
# Mean Accuracy: 0.689554, Parameters: {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'uniform'}
# Mean Accuracy: 0.729856, Parameters: {'metric': 'manhattan', 'n_neighbors': 4, 'weights': 'distance'}
# Mean Accuracy: 0.694579, Parameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'uniform'}
# Mean Accuracy: 0.712720, Parameters: {'metric': 'manhattan', 'n_neighbors': 5, 'weights': 'distance'}
# Mean Accuracy: 0.677428, Parameters: {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'uniform'}
# Mean Accuracy: 0.710700, Parameters: {'metric': 'manhattan', 'n_neighbors': 6, 'weights': 'distance'}
# Mean Accuracy: 0.689528, Parameters: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'uniform'}
# Mean Accuracy: 0.703639, Parameters: {'metric': 'manhattan', 'n_neighbors': 7, 'weights': 'distance'}
# Mean Accuracy: 0.690528, Parameters: {'metric': 'manhattan', 'n_neighbors': 8, 'weights': 'uniform'}
# Mean Accuracy: 0.711695, Parameters: {'metric': 'manhattan', 'n_neighbors': 8, 'weights': 'distance'}
# Mean Accuracy: 0.694559, Parameters: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'uniform'}
# Mean Accuracy: 0.710680, Parameters: {'metric': 'manhattan', 'n_neighbors': 9, 'weights': 'distance'}
# Mean Accuracy: 0.691508, Parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'uniform'}
# Mean Accuracy: 0.712685, Parameters: {'metric': 'manhattan', 'n_neighbors': 10, 'weights': 'distance'}
# Mean Accuracy: 0.694528, Parameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'uniform'}
# Mean Accuracy: 0.710654, Parameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
# Mean Accuracy: 0.692518, Parameters: {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'uniform'}
# Mean Accuracy: 0.709654, Parameters: {'metric': 'manhattan', 'n_neighbors': 12, 'weights': 'distance'}
# Mean Accuracy: 0.701584, Parameters: {'metric': 'manhattan', 'n_neighbors': 13, 'weights': 'uniform'}
# Mean Accuracy: 0.713680, Parameters: {'metric': 'manhattan', 'n_neighbors': 13, 'weights': 'distance'}
# Mean Accuracy: 0.688478, Parameters: {'metric': 'manhattan', 'n_neighbors': 14, 'weights': 'uniform'}
# Mean Accuracy: 0.710659, Parameters: {'metric': 'manhattan', 'n_neighbors': 14, 'weights': 'distance'}
# Best parameters for KNN: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# Best KNN score: 0.879016293589158
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Dress       0.97      0.71      0.82        41
#     Hand_bag       0.79      0.93      0.85        41
#          Hat       0.95      0.91      0.93        43
#        Shirt       1.00      0.90      0.95        40
#        Shoes       0.98      0.93      0.95        44
#     Trousers       0.77      1.00      0.87        40
#
#     accuracy                           0.90       249
#    macro avg       0.91      0.90      0.89       249
# weighted avg       0.91      0.90      0.90       249
#
# Model saved to /content/drive/MyDrive/CS231_DT/Source_code/Model/knn_model_12_4_2.pkl
# '/content/drive/MyDrive/CS231_DT/Source_code/Model/knn_model_12_4_2.pkl'

# %%
def plot_knn_results(knn_grid):
    mean_accuracy = knn_grid.cv_results_['mean_test_score']
    n_neighbors = knn_grid.cv_results_['param_n_neighbors'].data
    weights = knn_grid.cv_results_['param_weights'].data
    metric = knn_grid.cv_results_['param_metric'].data

    plt.figure(figsize=(10, 6))

    for weight in ['uniform', 'distance']:
        for met in ['euclidean', 'manhattan']:
            mask = (weights == weight) & (metric == met)
            if np.any(mask):
                plt.plot(n_neighbors[mask], mean_accuracy[mask], marker='o', label=f'weight={weight}, metric={met}')

    plt.title('Mean Accuracy vs n_neighbors for KNN', fontsize=16, fontweight='bold', pad=10)
    plt.xlabel('n_neighbors', fontsize=12, fontweight='bold')
    plt.ylabel('Mean Accuracy', fontsize=12, fontweight='bold')
    plt.legend(title="KNN Parameters")
    plt.grid(True)
    plt.show()

plot_knn_results(knn_grid)

# %%
#Huấn luyện và đánh giá bằng SVM
svm_params = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [0.1, 1, 10, 100],
    'gamma': ['scale', 'auto']
}

# Khởi tạo StratifiedKFold để chia dữ liệu thành 5 folds (k=5)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

svm_grid = GridSearchCV(
    estimator=SVC(),
    param_grid=svm_params,
    scoring='accuracy',
    cv=cv,
    verbose=1
)

svm_grid.fit(hog_train_feature, y_train)

os.makedirs(results_path, exist_ok=True)
results_file = os.path.join(results_path, f'result_svm_12_4_2.txt')
save_results(results_file, svm_grid.cv_results_)

print("Best parameters for SVM:", svm_grid.best_params_)
print("Best SVM score:", svm_grid.best_score_)

evaluate_model(svm_grid.best_estimator_, hog_test_feature, y_test, class_names)

save_model(svm_grid.best_estimator_, model_path, f'svm_model_12_4_2.pkl')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits

# %%
def plot_svm_results(svm_grid):
    mean_accuracy = svm_grid.cv_results_['mean_test_score']
    kernel = svm_grid.cv_results_['param_kernel'].data
    C_values = svm_grid.cv_results_['param_C'].data
    gamma = svm_grid.cv_results_['param_gamma'].data

    kernels = ['linear', 'rbf', 'poly']

    for ker in kernels:
        plt.figure(figsize=(10, 6))
        for gam in ['scale', 'auto']:
            mask = (kernel == ker) & (gamma == gam)
            if np.any(mask):
                plt.plot(C_values[mask], mean_accuracy[mask], marker='o', label=f'gamma={gam}')

        plt.title(f'Mean Accuracy vs C for SVM (Kernel: {ker})', fontsize=16, fontweight='bold', pad=10)
        plt.xlabel('C', fontsize=12, fontweight='bold')
        plt.ylabel('Mean Accuracy', fontsize=12, fontweight='bold')
        plt.legend(title="Gamma")
        plt.grid(True)
        plt.show()

plot_svm_results(svm_grid)

# %%
#Huấn luyện và đánh giá cho Random Forest
rf_params = {
    'n_estimators': [10, 50, 100, 150, 200, 250],
    'max_depth': [None, 10, 20, 30, 40, 50]
    }

rf_grid = train_model_with_gridsearch(
    X_train=hog_train_feature,
    y_train=y_train,
    model=RandomForestClassifier(),
    param_grid=rf_params)

os.makedirs(results_path, exist_ok=True)
results_file = os.path.join(results_path, f'result_rf_12_4_2.txt')
save_results(results_file, rf_grid.cv_results_)

print("Best parameters for RF:", rf_grid.best_params_)
print("Best RF score:", rf_grid.best_score_)

evaluate_model(rf_grid.best_estimator_, hog_test_feature, y_test, class_names)

save_model(rf_grid.best_estimator_, model_path, f'rf_model_12_4_2.pkl')
# Out:
# Mean Accuracy: 0.880006, Parameters: {'max_depth': None, 'n_estimators': 10}
# Mean Accuracy: 0.921359, Parameters: {'max_depth': None, 'n_estimators': 50}
# Mean Accuracy: 0.932435, Parameters: {'max_depth': None, 'n_estimators': 100}
# Mean Accuracy: 0.932460, Parameters: {'max_depth': None, 'n_estimators': 150}
# Mean Accuracy: 0.931425, Parameters: {'max_depth': None, 'n_estimators': 200}
# Mean Accuracy: 0.930430, Parameters: {'max_depth': None, 'n_estimators': 250}
# Mean Accuracy: 0.868951, Parameters: {'max_depth': 10, 'n_estimators': 10}
# Mean Accuracy: 0.925379, Parameters: {'max_depth': 10, 'n_estimators': 50}
# Mean Accuracy: 0.929400, Parameters: {'max_depth': 10, 'n_estimators': 100}
# Mean Accuracy: 0.926390, Parameters: {'max_depth': 10, 'n_estimators': 150}
# Mean Accuracy: 0.930420, Parameters: {'max_depth': 10, 'n_estimators': 200}
# Mean Accuracy: 0.933455, Parameters: {'max_depth': 10, 'n_estimators': 250}
# Mean Accuracy: 0.877996, Parameters: {'max_depth': 20, 'n_estimators': 10}
# Mean Accuracy: 0.922354, Parameters: {'max_depth': 20, 'n_estimators': 50}
# Mean Accuracy: 0.932450, Parameters: {'max_depth': 20, 'n_estimators': 100}
# Mean Accuracy: 0.933445, Parameters: {'max_depth': 20, 'n_estimators': 150}
# Mean Accuracy: 0.928405, Parameters: {'max_depth': 20, 'n_estimators': 200}
# Mean Accuracy: 0.934460, Parameters: {'max_depth': 20, 'n_estimators': 250}
# Mean Accuracy: 0.864900, Parameters: {'max_depth': 30, 'n_estimators': 10}
# Mean Accuracy: 0.924359, Parameters: {'max_depth': 30, 'n_estimators': 50}
# Mean Accuracy: 0.926395, Parameters: {'max_depth': 30, 'n_estimators': 100}
# Mean Accuracy: 0.935465, Parameters: {'max_depth': 30, 'n_estimators': 150}
# Mean Accuracy: 0.927415, Parameters: {'max_depth': 30, 'n_estimators': 200}
# Mean Accuracy: 0.935465, Parameters: {'max_depth': 30, 'n_estimators': 250}
# Mean Accuracy: 0.868905, Parameters: {'max_depth': 40, 'n_estimators': 10}
# Mean Accuracy: 0.925379, Parameters: {'max_depth': 40, 'n_estimators': 50}
# Mean Accuracy: 0.932430, Parameters: {'max_depth': 40, 'n_estimators': 100}
# Mean Accuracy: 0.938496, Parameters: {'max_depth': 40, 'n_estimators': 150}
# Mean Accuracy: 0.934460, Parameters: {'max_depth': 40, 'n_estimators': 200}
# Mean Accuracy: 0.931445, Parameters: {'max_depth': 40, 'n_estimators': 250}
# Mean Accuracy: 0.861860, Parameters: {'max_depth': 50, 'n_estimators': 10}
# Mean Accuracy: 0.926384, Parameters: {'max_depth': 50, 'n_estimators': 50}
# Mean Accuracy: 0.932425, Parameters: {'max_depth': 50, 'n_estimators': 100}
# Mean Accuracy: 0.928405, Parameters: {'max_depth': 50, 'n_estimators': 150}
# Mean Accuracy: 0.933460, Parameters: {'max_depth': 50, 'n_estimators': 200}
# Mean Accuracy: 0.933460, Parameters: {'max_depth': 50, 'n_estimators': 250}
# Best parameters for RF: {'max_depth': 40, 'n_estimators': 150}
# Best RF score: 0.9384955078422414
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Dress       0.86      0.90      0.88        41
#     Hand_bag       0.95      0.85      0.90        41
#          Hat       0.87      0.91      0.89        43
#        Shirt       0.95      1.00      0.98        40
#        Shoes       0.98      0.93      0.95        44
#     Trousers       0.93      0.93      0.93        40
#
#     accuracy                           0.92       249
#    macro avg       0.92      0.92      0.92       249
# weighted avg       0.92      0.92      0.92       249
#
# Model saved to /content/drive/MyDrive/CS231_DT/Source_code/Model/rf_model_12_4_2.pkl
# '/content/drive/MyDrive/CS231_DT/Source_code/Model/rf_model_12_4_2.pkl'

# %%
# Trích xuất kết quả và tạo biểu đồ cho RF
def plot_rf():
    mean_accuracy = rf_grid.cv_results_['mean_test_score']
    n_estimators = rf_grid.cv_results_['param_n_estimators'].data
    max_depth = rf_grid.cv_results_['param_max_depth'].data

    plt.figure(figsize=(10, 6))

    mask = (max_depth == None)
    if np.any(mask):
        plt.plot(n_estimators[mask], mean_accuracy[mask], marker='o', label='max_depth = None')
    for depth in [10, 20, 30]:
        mask = (max_depth == depth)
        plt.plot(n_estimators[mask], mean_accuracy[mask], marker='o', label=f'max_depth = {depth}')

    plt.title('Mean Accuracy vs n_estimators', fontsize=16, fontweight='bold', pad=10)
    plt.xlabel('n_estimators', fontsize=12, fontweight='bold')
    plt.ylabel('Mean Accuracy', fontsize=12, fontweight='bold')
    plt.legend(title="Max Depth")
    plt.show()
plot_rf()
